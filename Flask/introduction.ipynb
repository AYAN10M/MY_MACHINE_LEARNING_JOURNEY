# %% [markdown]
# Flask is a micro web framework written in Python. It's classified as a "micro" framework because it doesn't require any particular tools or libraries, making it lightweight and flexible.
#
#
# Purpose of Flask is to build web applications, APIs, and websites in Python.
#
# We will learnt about the following:
# 1. WSGI (Web Server Gateway Interface)
# 2. Jinja2 Template Engine

# %% [markdown]
# Learn about WSGI from [here](https://medium.com/@arashtad/what-is-wsgi-and-why-is-it-necessary-9177645ed7e2)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Jinja 2 is a modern and designer-friendly templating language for Python, modelled after Django’s templates. It is fast, widely used and secure with the optional sandboxed template execution environment.
#
# ![template_rendering.png](attachment:template_rendering.png)
#
# This context data could be anything like a ML model output, a database query result, or a simple string. The template engine will render the template with the context data and return the final HTML to the client.
